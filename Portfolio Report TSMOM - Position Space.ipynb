# %%
# %matplotlib inline
from marketdata import *
from model import *
from analytics import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
from datetime import datetime

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# # Load data
#
# Try clean up markets with 100% close out values

# %%
mkts=get_market_list()

# %%
df=pd.DataFrame()
for m in mkts:
    try:
        df[m]=get_timeseries(m)
    except:
        print m

# %% [markdown]
# # Try many different look backs

# %%
pnl_with_lookbacks=pd.DataFrame()
FundAUM=1e6
curr_px=get_most_liquid_price(mkts)
for l in range(5,250,5):
    pos=tsmom_daily(df[mkts],l)
    pnl=calc_pnl_wc(pos,df[mkts])
    scaling_factor=calc_scaling_factor(pnl)
    s=tsmom_daily_signal(df,l)
    lots=calc_position(s,FundAUM,scaling_factor,curr_px)
    PNL = calc_pnl_position_wc(lots,df,curr_px)
    pnl_with_lookbacks[str(l)]= (PNL.sum(axis=1)/FundAUM).dropna()
# Out:
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=25,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=25,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=30,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=30,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=35,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=35,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=40,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=40,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=45,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=45,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=50,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=50,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=55,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=55,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=60,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=60,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=65,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=65,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=70,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=70,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=75,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=75,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=80,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=80,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=85,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=85,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=90,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=90,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=95,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=95,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=100,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=100,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=105,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=105,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=110,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=110,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=115,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=115,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=120,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=120,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=125,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=125,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=130,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=130,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=135,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=135,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=140,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=140,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=145,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=145,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=150,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=150,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=155,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=155,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=160,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=160,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=165,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=165,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=170,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=170,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=175,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=175,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=180,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=180,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=185,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=185,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=190,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=190,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=195,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=195,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=200,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=200,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=205,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=205,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=210,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=210,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=215,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=215,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=220,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=220,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=225,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=225,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=230,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=230,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=235,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=235,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=240,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=240,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:8: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=245,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)
# model.py:16: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=245,center=False).mean()
#   signal=pd.rolling_mean(data,signal_lookback)

# %%
pnl_with_lookbacks.cumsum().plot(colormap='jet')

# %%
calc_Sharpe(pnl_with_lookbacks,250).plot(kind='bar',title='Sharpe Ratio')

# %%
(pnl_with_lookbacks.std()*16).plot(kind='bar',title='Volatility',colormap='jet')

# %%
sns.heatmap(pnl_with_lookbacks.corr())

# %% [markdown]
# Drawdown analysis

# %%
temp=(pnl_with_lookbacks.resample(rule='m',how='sum')+1).cumprod()
(temp/pd.rolling_max(temp,1000000,min_periods=1)).plot(colormap='jet')
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   if __name__ == '__main__':
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: FutureWarning: pd.rolling_max is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=1,window=1000000,center=False).max()
#   from IPython.kernel.zmq import kernelapp as app

# %%
temp2=(1-(temp/pd.rolling_max(temp,1000000,min_periods=1)).min())
temp2.plot(kind='bar',colormap='jet',title='Max Drawdown')
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: pd.rolling_max is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=1,window=1000000,center=False).max()
#   if __name__ == '__main__':
